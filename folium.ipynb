# %%
import folium

nodes_map = folium.Map(location=[30.507997, 114.343159], zoom_start=10.4)
 
def mark(lat,lng,name):
    res = folium.Marker(
    location=[lat, lng],
    popup= name,
    icon=folium.Icon(color='blue', icon='info-sign')    # 标记颜色  图标
    ).add_to(nodes_map)
    return res

folium.Marker(
    location=[30.507997, 114.343159],
    popup='中百仓储(南湖购物广场店)',
    icon=folium.Icon(color='red', icon='info-sign')    # 标记颜色  图标
).add_to(nodes_map)

mark(30.524004,114.367216,'华中师范大学')
mark(30.542779,114.319833,'中南财经政法大学(首义校区)')
mark(30.382144,114.344906,'武汉纺织大学(阳光校区)')
mark(30.739369,114.423047,'武汉文理学院')
mark(30.480725,114.392191,'中南财经政法大学(南湖校区)')
mark(30.481780,114.363708,'华中农业大学')
mark(30.718908,114.533094,'武汉生物工程学院')
mark(30.652282,114.590649,'湖北大学(阳逻校区)')
mark(30.517062,114.438204,'华中科技大学(东校区)')
mark(30.526212,114.357936,'武汉理工大学(马房山校区)')
mark(30.519799,114.350349,'武汉理工大学(鉴湖校区)')
mark(30.543803,114.372930,'武汉大学(文理学部)')
mark(30.525749,114.408655,'中国地质大学')
mark(30.491874,114.399395,'中南民族大学')
mark(30.521832,114.346817,'武汉科技大学')
mark(30.485946,114.278973,'江汉大学(武昌校区)')
mark(30.526661,114.385028,'武汉体育学院')
mark(30.523080,114.435704,'华中科技大学附属中学')
mark(30.542716,114.335151,'武汉市武珞路实验初级中学')
mark(30.610466,114.317788,'武汉二中广雅中学')
mark(30.502163,114.415332,'武汉市关山中学')
mark(30.441373,114.456665,'武汉市光谷第二高级中学')
mark(30.553490,114.318588,'武汉中学')
mark(30.557894,114.309996,'湖北省武昌实验中学')
mark(30.537842,114.360136,'武汉市洪山中学')
mark(30.555396,114.352807,'湖北省水果湖高级中学')

nodes_map.save('nodes.html')

# %%
import folium

routes_map = folium.Map(location=[30.507997, 114.343159], zoom_start=10.4)

def mark(lat,lng,name):
    res = folium.Marker(
    location=[lat, lng],
    popup= name,
    icon=folium.Icon(color='blue', icon='info-sign')    # 标记颜色  图标
    ).add_to(routes_map)
    return res

folium.Marker(
    location=[30.507997,114.343159],
    popup='中百仓储(南湖购物广场店)',
    icon=folium.Icon(color='red', icon='info-sign')    # 标记颜色  图标
).add_to(routes_map)

#   [30.507997,114.343159]#0
mark(30.524004,114.367216,'华中师范大学')#1
mark(30.542779,114.319833,'中南财经政法大学(首义校区)')#2
mark(30.382144,114.344906,'武汉纺织大学(阳光校区)')#3
mark(30.739369,114.423047,'武汉文理学院')#4
mark(30.480725,114.392191,'中南财经政法大学(南湖校区)')#5
mark(30.481780,114.363708,'华中农业大学')#6
mark(30.718908,114.533094,'武汉生物工程学院')#7
mark(30.652282,114.590649,'湖北大学(阳逻校区)')#8
mark(30.517062,114.438204,'华中科技大学(东校区)')#9
mark(30.526212,114.357936,'武汉理工大学(马房山校区)')#10
mark(30.519799,114.350349,'武汉理工大学(鉴湖校区)')#11
mark(30.543803,114.372930,'武汉大学(文理学部)')#12
mark(30.525749,114.408655,'中国地质大学')#13
mark(30.491874,114.399395,'中南民族大学')#14
mark(30.521832,114.346817,'武汉科技大学')#15
mark(30.485946,114.278973,'江汉大学(武昌校区)')#16
mark(30.526661,114.385028,'武汉体育学院')#17
mark(30.523080,114.435704,'华中科技大学附属中学')#18
mark(30.542716,114.335151,'武汉市武珞路实验初级中学')#19
mark(30.610466,114.317788,'武汉二中广雅中学')#20
mark(30.502163,114.415332,'武汉市关山中学')#21
mark(30.441373,114.456665,'武汉市光谷第二高级中学')#22
mark(30.553490,114.318588,'武汉中学')#23
mark(30.557894,114.309996,'湖北省武昌实验中学')#24
mark(30.537842,114.360136,'武汉市洪山中学')#25
mark(30.555396,114.352807,'湖北省水果湖高级中学')#26

folium.PolyLine([
    [30.507997,114.343159],
    [30.557894,114.309996],
    [30.610466,114.317788],
    [30.718908,114.533094],
    [30.652282,114.590649],
    [30.739369,114.423047],
    [30.553490,114.318588],
    [30.507997,114.343159],
],color='#dc143c').add_to(routes_map)
folium.PolyLine([
    [30.507997,114.343159],
    [30.382144,114.344906],
    [30.480725,114.392191],
    [30.491874,114.399395],
    [30.441373,114.456665],
    [30.524004,114.367216],
    [30.507997,114.343159],
],color='#c71585').add_to(routes_map)
folium.PolyLine([
    [30.507997,114.343159],
    [30.526661,114.385028],
    [30.525749,114.408655],
    [30.523080,114.435704],
    [30.517062,114.438204],
    [30.507997,114.343159],
],color='#5fff27').add_to(routes_map)
folium.PolyLine([
    [30.507997,114.343159],
    [30.521832,114.346817],
    [30.526212,114.357936],
    [30.543803,114.372930],
    [30.555396,114.352807],
    [30.507997,114.343159],
],color='blue').add_to(routes_map)
folium.PolyLine([
    [30.507997,114.343159],
    [30.537842,114.360136],
    [30.542716,114.335151],
    [30.542779,114.319833],
    [30.507997,114.343159],
],color='#9400d3').add_to(routes_map)
folium.PolyLine([
    [30.507997,114.343159],
    [30.519799,114.350349],
    [30.485946,114.278973],
    [30.481780,114.363708],
    [30.507997,114.343159],
],color='#00686d').add_to(routes_map)

routes_map.save('routes.html')
